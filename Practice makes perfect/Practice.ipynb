# %%
x = input ('waht is your name ')
print (x)
print ("welcome " + (x))
# Out:
# ahmed
# welcome ahmed

# %%
x = int (input ("plz enter your first number "))
yo = int (input ('the second number plz'))
print (x +2/ yo)
# Out:
# 3.0

# %%
my_list = [4,5,6,7]
print (my_list[0], my_list[-1], len(my_list))
# Out:
# 4 7 4

# %%
for i in  range (1,6):
    print (i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
why = [2,4,5,9,1]
for item in why:
    if item %2==0:
        print (item)
# Out:
# 2
# 4

# %%
x = int (input('enter a num'))
for i in range (1, x + 1):
    print(i)
if i % 3==0 and i % 5==0:
    print ("FizzBuzz")
elif i % 3 == 0:
    print ('fizz')
elif i % 5==0:
    print ('buzz')
else:
    print (i)
# Out:
# 1
# 1

# %%
for i in range(1,11):
    if i % 2 == 0:
        print (i)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
print("Hello, World!")
# Out:
# Hello, World!
