# %%
numx=22
numw=2.1
sum=numx+numw
print(sum)

# %%
name=input("Enter your name")
age=input("Enter your age")
print(name)
print(age)

# %%
gmail=input("Enter your Email")
password0=input("enter your password")
print("welcome")

# %%
x=50
q=10
w=40
print(x+q+w)

# %%
A=input("Enter the first number")
B=input("Enter the second number")
C=input("Enter the third number")
A=float (A)
B=float (B)
C=float (C)
WWE=A+B+C
print(WWE)

# %%
x=5
y=6

# %%
x>y

# %%
X='i am data scientist'
print(X [5:9:1])

# %%
X='i am data scientist'
print(X [-1:-10:-1])

# %%
X='i am data scientist'
x=x.upper()
print(x)

# %%
X='i am data scientist'
x=x.title()
print(x)

# %%
X='i am data scientist'
x=x.lower()
print(x)

# %%
yo = input ("Enter a word")
print (yo[::1])

# %%
yo=input("Enter a float number")
y=yo.split('.')
print(y)

# %%
x = "awesome"
print("python is " + x)

# %%
x = y = z = 50
print (x)
print(y)
print(z)

# %%
x = 6
print(x)
del X
print(x)

# %%
x = 'i am data scientist'
x=x.replace('am' ,'is')
print(x)

# %%
x = input ("enter a word")
x=x.replace('a' , 'A')
print (x)

# %%
x = 'i am data scientist'
x=x.split(',')
print(x)

# %%
x = '  i am data scientist  '
x=x.strip()
print(x)

# %%
x ='i am data scientist'
y="i am an ai engineer"
print(x+','+y)

# %%
name = input ("enter your name")
print (name * 5)

# %% [markdown]
# # EX1 : Write program to initialize three variable with diffrent data types the first 2 are numerical data types and output them to user

# %%
x = 1
y = 2.5
z = 'ahmed'
print(x)
print(y)
print(z)
print(x,y,z)

# %% [markdown]
# ## EX2 : Write program to add the first two variables you have initialized and put the answer in another variable then print answer

# %%
 
s = x + y
print(s)

# %%
## EX3 : write a program to take name and age as an input from user  and print name and age as output 
x = int(input('please enter your age : '))
y = input('please enter your name : ')
print(x)
print(y)

# %%
## EX4 : write a program to take E-mail and Password as an input from user and print the output in a welcome message  
x = input('please enter your email : ')
y = input('please enter your password : ')
print(f'welcome your email is : {x}\nyour password is : {y}')

# %%
## EX5 : write a program to accept three numbers from user and add this numbers x = float(input('please enter your first number : '))
x = float(input('please enter your first number : '))
y = float(input('please enter your second number : '))
z = float(input('please enter your third number : '))
s = x + y + z
s

# %%
## EX6 : write program to ask user for circle radius and calculate area  
r = float(input('please enter the radius : '))
area = 3.14 * (r**2) 
area

# %%
## EX7 : write program to ask user for square side length and compute area 
l = float(input('please enter side length of square : '))
area = l*l
area

# %%
## EX8 : write a program that accept from user 2 numbers and make simple calculator on it (print the addition,subtraction.multiplication , divison)
x = float(input('please enter your first number : '))
y = float(input('please enter your second number : '))
s = x + y
sub = x - y
multi = x * y
divi = x / y
floor_divi = x // y
print(f'sum is equal : {s}\nsubtraction equal : {sub}\nmultiplaction equal : {multi}\nnormal equal : {divi}\nfloor division equal : {floor_divi}')

# %%
### EX9 : Print your triple name  in three lines (with 3 ways) 
x = 'ahmed'
print('ahmed')
print('ahmed')
print('ahmed')
print('-'*20)
print(f'{x}\n{x}\n{x}')
print('-'*20)
print('ahmed\nahmed\nahmed')

# %%
 
 ##EX10 : ask user to enter word and print only characters with even index using slicing
x = input('please enter your word')
y = x[0::2]
print(y)
print(x[0::2])

# %%
## EX11 : ask user to enter word and print only characters with odd index using slicing 
x = input('please your word : ')
y = x[1::2]
print(y)
print(x[1::2])

# %%
## EX12 : ask user to enter word and print this word reversed 
x = input('please enter your name : ')
y = x[::-1]
print(y)
z = y[1::2]
print(z)

# %%
## EX13: ask user to enter float number and seperate integer part  and floating part in  using strings 
x = input('please your floating number : ')
y = x.split('.')
f_1 = y[0]
f_2 = y[1]
print(f'the integer is equal : {f_1}\nthe floating numer is : {f_2}')

# %%
## EX14: ask user to enter string and this string contains at least one (a) character replace the first occurrence of this character only to it's upper case 
x = input('please enter your name contains at least 1 (a) : ')
y = x.replace('a','A',1)
y

# %%
## EX15: Write a Python program that asks the user to enter three exam scores, calculates the average of the three numbers, and prints the average
x = float(input('please enter your first score : '))
y = float(input('please enter your second score : '))
z = float(input('please enter your third score : '))
avg = (x+y+z) / 3
avg

# %%
## EX16:Write a Python program that asks the user for two numbers, subtracts the second number from the first, and prints the result.
x = float(input('please enter your first number : '))
y = float(input('please enter your second number : '))
sub = y - x 
print(f'subtraction is equal : {sub}')

# %%
##EX17 Write a Python program that takes a user’s name as input, removes extra spaces and prints the cleaned name.
x = input('please enter your name : ')
y = x.split()
print(y)
cleaned_name = ''.join(y)
print(cleaned_name)

# %%
## EX18 : Write a Python program that stores a word in a variable and prints that word repeated three times in one line.
x = input('enter your name : ')
print(x,x,x)

# %%
## EX19: Write a Python program that asks the user for the price of a product, adds 15% tax to it, and prints the final price.
x = float(input('please product price : '))
y = x + (x*0.15)
print(f'final is equal : {y}')

# %%
## EX20:Write a Python program that asks the user to enter their first name and prints only the first 3 letters using slicing.
x = input('enter name : ')
y = x[0:3]
y

# %% [markdown]
# ## >< >= != == numbers

# %%
x = 10
y = 5
result = x > y
print (result)

# %%
number = 7
if number > 5:
    print('5 is bigger')
else:
    print("5 is small")

# %%
numbers = [1, 3, 5, 7, 9,]
for num in numbers:
    if num > 5:
        print(f"{num} 5 bigger")
else:
    print (f"{5} 5 is small")

# %% [markdown]
# ## >< >= != == intger

# %%
text1 = "apple"
text2 = "banana"
result = text1 < text2
print (result)

# %%
letter = "c"
if letter < "d":
    print("c comes befor d")
else:
    print("c comes after d")

# %%
letters = ["a," "c," "b,"]
for i in letters:
    if i < "d":
        print(i, "is before d")
    else:
        print(i, "is after d")

# %% [markdown]
# ## if elif else

# %%
x=int(input("Enter an integer"))
if x==5:
    print("True")
else :
    print('false')

print(type(x))

# %%
num1=float(input("enter the first number"))
num2=float(input("enter the second number"))
if num1 > num2 :
    print ("first number is bigger")
elif num2>num1:
    print('second number is bigger')
else:
    print("numbers are equal")

# %%
x=float(input('enter a number to check'))

if x>0:
    print('number is postive')
elif x<0:
    print('number is negative')
else:
    print('number is zero')

# %%
#i am omr

'''
i am omar
'''
x=int(input('enter a number to check'))
if x==0:
    print("x isnot even or odd")
elif x%2 ==0:
    print("number is even")
else :
    print('number is odd')

# %%
x= int(input('Enter the number to check'))
if x%2==0 :
    if x%3==0:
        print('condition is true')
    else:
        print('number is divisible by 2 only')
else:
    print('codition is false')

# %%
x= int(input('Enter the number to check'))
if x%2==0 and x%3==0:
    print('condtion is true')
else:
    print('condtion is not true')

# %%
text=input('Enter a sentence')
if text.isupper():
    print(text,', the sentence is already capital')
else:
    print(text.upper(),', the sentemce was small')

# %%
word=input('enter a word')
chc=input('Enter a  character')
if word.find(chc)==-1:
    print('character ',chc ,' isnot in word')
else:
    print('character ',chc ,' is in word',word.find(chc))

# %%
word=input('enter a word')
chc=input('Enter a  character')
if chc in word:
    print ('character is in word')
else:
    print('character is not in word')

# %% [markdown]
# ## loops and if

# %%
check=''
while check != 'N':
    num1=float(input('enter first number'))
    num2=float(input('enter second number'))
    op=input('enter the operation (+,-,*,/)')
    
        
    if op == '+':
        result=num1+num2
        print('answer is',result)
    elif op =='-':
        result=num1-num2
        print('answer is',result)
    elif op =='*':
        result=num1*num2
        print('answer is',result)
    elif op =='/':
        if num2 ==0:
            print('denomenator cant be zero')
        else:
            result=num1/num2
            print('answer is',result)
    else :
        print('enter a valid operation')
    check=input('Do u want to continue? Y/N')

# %%
sum=0
for i in range(1,11):
    sum=sum+i
print(sum)

# %%
for i in range(2, 10, 2):
    print("i =", i)

# %%
for i in range(10):
    print("i =", i)

# %%
count = 1
while count <= 5:
    print(count)
    count += 1

# %%
total = 0
number= 1
while total < 10:
    total += number
    number += 1
    print(total)

# %%
sum=0
for i in range(1,11):
    sum=sum+i
    print(sum)

# %%
names = ["ali", 'ahmed', 'sara', 'omar']
for name in names:
    print('hello, '+ name + "!")

# %% [markdown]
# ## def

# %%
def my_function():
    print("hello and welcome to my function")
my_function()

# %%
def add_numbers(a,b):
    return a + b
result = add_numbers(3 , 5)
print (result)

# %%
def print_greeting(name):
    print("hello, " + name + "!")
print_greeting("Ahmed")

# %%
def X():
    print("hello, world!")
X()

# %%
def say_hi(name):
    print("Hello " + name)
say_hi("AHMED")

# %%
def say_hi(name, age):
    print("Hello "  + name + "your age is " +age)
say_hi("AHMED " , "19")

# %%
def cube(num):
   return num*num*num

result = cube(4)
print (result)

def sum(num1, num2):
   return num1+num2
print(sum(2,4))

# %% [markdown]
# ## list

# %%
my_list = [1,2,3,4,5]
for item in my_list:
    print(item)

# %%
my_list.append(6)
print(my_list)

# %% [markdown]
# ## Dictionaries

# %%
my_dict = {"a": 1, "b": 2, "C": 3}
key = "a"
while key in my_dict:
    print(my_dict[key])
    key = chr (ord(key) + 1)

# %%
person = {"name": "ahmed", "age": 19}
print (person)

# %%
grades = {'ahmed': 90,
          'sara': 85,
          'ali': 75}
print(f"ahmed grades: {grades['ahmed']}")

# %% [markdown]
# ## tuples

# %%
my_tuple = (1,2,3,4)
print (my_tuple)

# %% [markdown]
# ## sets

# %%
my_set = {1,2,3,4}
print (my_set)
