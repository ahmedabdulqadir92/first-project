# %%
! pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 26.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/51/27/bf9436dd0a4fc3130acec0828951c7ef96a0631969613a9a35744baf27f6/pandas-3.0.0-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for tzdata from https://files.pythonhosted.org/packages/c7/b0/003792df09decd6849a5e39c28b513c06e84436a54440380862b5aeff25d/tzdata-2025.3-py2.py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB 640.0 kB/s eta 0:00:16
#    ---------------------------------------- 0.1/9.9 MB 919.0 kB/s eta 0:00:11
#     --------------------------------------- 0.2/9.9 MB 1.7 MB/s eta 0:00:06
#    - -------------------------------------- 0.4/9.9 MB 2.1 MB/s eta 0:00:05
# ...

# %%
import pandas as pd
import numpy as np

# %%
s1=pd.Series([1,2,3,4],index=['ahmed','said','hussien','ali'])
s1
# Out:
# ahmed      1
# said       2
# hussien    3
# ali        4
# dtype: int64

# %%
s1=pd.Series([1,2,3,4],index=['ahmed','said','hussien','ali'])
s1['ali']
# Out:
# np.int64(4)

# %%
arr=np.array([1,2,3,4,5])
s1=pd.Series([1,2,3,4],index=['ahmed','said','hussien','ali'])
s1.iloc[1]
s2=pd.Series(arr,index=['a','s','h','v','x'])
s2
# Out:
# a    1
# s    2
# h    3
# v    4
# x    5
# dtype: int64

# %%
arr=np.array([1,2,3,4,5])
s1=pd.Series([1,2,3,4],index=['ahmed','said','hussien','ali'])
s1.iloc[1]
s2=pd.Series(arr,index=['a','s','h','v','x'])
s2.values
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr=np.array([1,2,3,4,5])
s1=pd.Series([1,2,3,4],index=['ahmed','said','hussien','ali'])
s1.iloc[1]
s2=pd.Series(arr,index=['a','s','h','v','x'])
s2.index
# Out:
# Index(['a', 's', 'h', 'v', 'x'], dtype='str')

# %%
arr=np.array([1,2,3,4,5])
s1=pd.Series([1,2,3,4],index=['ahmed','said','hussien','ali'])
s1.iloc[1]
s2=pd.Series(arr,index=['a','s','h','v','x'])
s2+10
# Out:
# a    11
# s    12
# h    13
# v    14
# x    15
# dtype: int64

# %%
df1=pd.DataFrame({'name':['omar','ahmed','hosssam'],
                  'age':[10,20,30],
                  'job':['doctor','engineer','accountant']})
df1
# Out:
#       name  age         job
# 0     omar   10      doctor
# 1    ahmed   20    engineer
# 2  hosssam   30  accountant

# %%
df1=pd.DataFrame({'name':['omar','ahmed','hossam'],
'age':[10,20,30],
'job':['doctor','engineer','accountant']})
df1
records=[{'name':'omar','age':15,'job':'eng'},
         {'name':'said','age':50,'job':'doc'},
         {'name':'fawzy','age':40,'job':'lawyer'}]
df2=pd.DataFrame(records)
df2
# Out:
#     name  age     job
# 0   omar   15     eng
# 1   said   50     doc
# 2  fawzy   40  lawyer

# %%
records=[{'name':'omar','age':15,'job':'eng'},
         {'name':'said','age':50,'job':'doc'},
         {'name':'fawzy','age':40,'job':'lawyer'}]
df2=pd.DataFrame(records)
df2
# Out:
#     name  age     job
# 0   omar   15     eng
# 1   said   50     doc
# 2  fawzy   40  lawyer

# %% [markdown]
# # domain knowledge

# %%
import pandas as pd
import plotly.express as px

df=pd.read_csv('titanic.csv')
df['fam_size']=df['Parch']+df['SibSp']
df=df.drop(columns=['SibSp','Parch'])
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age   Ticket  \
# 0                              Kelly, Mr. James    male  34.5   330911
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0   363272
# 2                     Myles, Mr. Thomas Francis    male  62.0   240276
# 3                              Wirz, Mr. Albert    male  27.0   315154
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0  3101298
#
#       Fare Cabin Embarked  fam_size
# 0   7.8292   NaN        Q         0
# 1   7.0000   NaN        S         1
# 2   9.6875   NaN        Q         0
# 3   8.6625   NaN        S         0
# 4  12.2875   NaN        S         2

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass              Name   Sex   Age  SibSp  Parch  \
# 0          892         0       3  Kelly, Mr. James  male  34.5      0      0
#
#    Ticket    Fare Cabin Embarked
# 0  330911  7.8292   NaN        Q

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
df.tail(1)
# Out:
#      PassengerId  Survived  Pclass                      Name   Sex  Age  \
# 417         1309         0       3  Peter, Master. Michael J  male  NaN
#
#      SibSp  Parch Ticket     Fare Cabin Embarked
# 417      1      1   2668  22.3583   NaN        C

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    str
#  4   Sex          418 non-null    str
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    str
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     str
#  11  Embarked     418 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 39.3 KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df.describe(include='object')
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_3648\87514550.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include='object')
#                     Name   Sex    Ticket            Cabin Embarked
# count                418   418       418               91      418
# unique               418     2       363               76        3
# top     Kelly, Mr. James  male  PC 17608  B57 B59 B63 B66        S
# freq                   1   266         5                3      270

# %%
df_numeric=df.drop(columns=['Name','Sex','Ticket','Cabin','Embarked'])
df_numeric['realatives']=df_numeric['sibSp']+df_numeric['Parch']
df_numeric.head()
df_numeric[['realatives','SibSp']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sibSp'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[65], line 2
# ...

# %%
df.loc[400]
# Out:
# PassengerId                       1292
# Survived                             1
# Pclass                               1
# Name           Bonnell, Miss. Caroline
# Sex                             female
# Age                               30.0
# SibSp                                0
# Parch                                0
# Ticket                           36928
# Fare                          164.8667
# Cabin                               C7
# Embarked                             S
# Name: 400, dtype: object

# %%
df.loc[[400,401,3,5,102]]['Survived'][400]
# Out:
# np.int64(1)

# %%
df_numeric>10
# Out:
#      PassengerId  Survived  Pclass    Age  SibSp  Parch   Fare
# 0           True     False   False   True  False  False  False
# 1           True     False   False   True  False  False  False
# 2           True     False   False   True  False  False  False
# 3           True     False   False   True  False  False  False
# 4           True     False   False   True  False  False   True
# ..           ...       ...     ...    ...    ...    ...    ...
# 413         True     False   False  False  False  False  False
# 414         True     False   False   True  False  False   True
# 415         True     False   False   True  False  False  False
# 416         True     False   False  False  False  False  False
# 417         True     False   False  False  False  False   True
#
# [418 rows x 7 columns]

# %%
df_numeric[df_numeric>10]
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch      Fare
# 0            892       NaN     NaN  34.5    NaN    NaN       NaN
# 1            893       NaN     NaN  47.0    NaN    NaN       NaN
# 2            894       NaN     NaN  62.0    NaN    NaN       NaN
# 3            895       NaN     NaN  27.0    NaN    NaN       NaN
# 4            896       NaN     NaN  22.0    NaN    NaN   12.2875
# ..           ...       ...     ...   ...    ...    ...       ...
# 413         1305       NaN     NaN   NaN    NaN    NaN       NaN
# 414         1306       NaN     NaN  39.0    NaN    NaN  108.9000
# 415         1307       NaN     NaN  38.5    NaN    NaN       NaN
# 416         1308       NaN     NaN   NaN    NaN    NaN       NaN
# 417         1309       NaN     NaN   NaN    NaN    NaN   22.3583
#
# [418 rows x 7 columns]

# %%
df_numeric[df_numeric>10].head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0          892       NaN     NaN  34.5    NaN    NaN      NaN
# 1          893       NaN     NaN  47.0    NaN    NaN      NaN
# 2          894       NaN     NaN  62.0    NaN    NaN      NaN
# 3          895       NaN     NaN  27.0    NaN    NaN      NaN
# 4          896       NaN     NaN  22.0    NaN    NaN  12.2875

# %%
df_numeric

# %%
df9=pd.read_csv('fifa_eda.csv')
df9
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# ...

# %%
x=df9.head()
print(x)
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# ...

# %%
df9.info
# Out:
# <bound method DataFrame.info of            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# ...

# %%
x=pd.read_csv ("imdb_movies")
x
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 x=pd.read_csv ("imdb_movies")
#       2 x
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
# ...
